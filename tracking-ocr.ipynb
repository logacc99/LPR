# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !pip install -qr requirements.txt  # install
# Out:
#      |████████████████████████████████| 596 kB 5.3 MB/s

# %%
from detect_test_thongphn import demo_image

# %%
demo_image('/content/drive/MyDrive/yolov5/data/images/car.png')
# Out:
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Initialize done.
# vehicle detected =  [[1476, 460, 1651, 561], [697, 413, 1182, 813], [386, 490, 539, 589]]
# label detected =  ['car', 'car', 'car']

# %%
from full_flow import demo_video
# Out:
# ...
# From /content/drive/My Drive/yolov5/full_flow.py:18: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
demo_video('/content/drive/MyDrive/yolov5/data/videos/night_testing.mp4')
# Out:
# Loading model successfully...
# Load sucessfully...
# Load sucessfully...
# Fusing layers...
# Initialize done.
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Initialize done.
# STEP 4: generating video...
# DONE!
